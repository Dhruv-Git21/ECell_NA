# %%
import pandas as pd
import datetime
import random
from collections import defaultdict

# Load data
startups = pd.read_csv("Startups.csv")
mentors = pd.read_csv("Mentor.csv")

# Fill empty fields with "any"
startups.fillna("any", inplace=True)
mentors.fillna("any", inplace=True)
print("[INFO] Data loaded and missing values filled.")

# Initialize time slots and schedules
start_time = datetime.datetime.strptime("11:00", "%H:%M")
end_time = datetime.datetime.strptime("14:00", "%H:%M")
time_slot_duration = datetime.timedelta(minutes=15)
gap_duration = datetime.timedelta(minutes=5)
print("[INFO] Time slots initialized.")

# Sector-wise distribution of startups
sector_startups = defaultdict(list)
for idx, row in startups.iterrows():
    sector_startups[row['sector']].append(idx)
print("[INFO] Sector-wise distribution of startups completed.")

# Mentor schedule and tracking
mentor_schedule = defaultdict(list)
mentor_startup_tracker = defaultdict(set)  # Tracks which startups each mentor has met
startup_mentor_count = defaultdict(int)    # Tracks how many times each startup has been allocated
allocated_startups = set()
print("[INFO] Mentor tracking and schedule initialized.")

# Probability distribution function
def get_startup_by_preference(mentor, preferences, bias=0.8):
    """
    Select a startup based on the mentor's preferences with a bias.
    """
    probabilities = [bias, (1 - bias) * 0.6, (1 - bias) * 0.4]  # Approximate 85% bias for first, split remaining
    for i, sector in enumerate(preferences):
        if sector in sector_startups and sector_startups[sector]:
            if random.random() <= probabilities[i]:  # Check probability
                return sector_startups[sector].pop(0)  # Allocate a startup
    return None  # No startup could be allocated from preferences

# Assign startups to mentors
def assign_startups():
    global allocated_startups
    print("[INFO] Starting the assignment of startups to mentors.")
    
    # Phase 1: Ensure all startups are allocated at least once
    while True:
        unallocated_startups = set(startups.index) - allocated_startups

        # Break if no unallocated startups are left
        if not unallocated_startups:
            print("[DEBUG] All startups have been allocated at least once.")
            break

        for _, mentor in mentors.iterrows():
            mentor_name = mentor['Name']
            preferences = [mentor['Sector 1'], mentor['Sector 2'], mentor['Sector 3']]

            # Allocate a startup based on preference probabilities
            current_time = start_time if not mentor_schedule[mentor_name] else datetime.datetime.strptime(
                mentor_schedule[mentor_name][-1][0], "%H:%M"
            ) + time_slot_duration + gap_duration
            current_time = max(current_time, start_time)  # Ensure time advances correctly

            if current_time >= end_time:
                print("[DEBUG] End time reached for mentor scheduling.")
                return

            startup_idx = get_startup_by_preference(mentor, preferences)
            if startup_idx is None:
                continue

            # Assign time slot and update tracking
            mentor_schedule[mentor_name].append((current_time.strftime("%H:%M"), startup_idx))
            mentor_startup_tracker[mentor_name].add(startup_idx)
            allocated_startups.add(startup_idx)
            startup_mentor_count[startup_idx] += 1
        
        print("[DEBUG] Completed one round of unallocated startups.")

    # Phase 2: Allow repetition with constraints
    while True:
        repeat_needed = False
        for _, mentor in mentors.iterrows():
            mentor_name = mentor['Name']
            preferences = [mentor['Sector 1'], mentor['Sector 2'], mentor['Sector 3']]

            current_time = start_time if not mentor_schedule[mentor_name] else datetime.datetime.strptime(
                mentor_schedule[mentor_name][-1][0], "%H:%M"
            ) + time_slot_duration + gap_duration

            if current_time >= end_time:
                print("[DEBUG] End time reached during repetition allocation.")
                return

            # Get startup ensuring it hasn't met the mentor more than once yet
            startup_idx = get_startup_by_preference(mentor, preferences)
            if startup_idx is None or startup_idx in mentor_startup_tracker[mentor_name]:
                continue  # Skip already met startups for this mentor

            # Limit the number of allocations to 5 per startup
            if startup_mentor_count[startup_idx] >= 5:
                continue

            # Assign time slot and update tracking
            mentor_schedule[mentor_name].append((current_time.strftime("%H:%M"), startup_idx))
            mentor_startup_tracker[mentor_name].add(startup_idx)
            startup_mentor_count[startup_idx] += 1
            repeat_needed = True
        if not repeat_needed:
            print("[DEBUG] Repetition allocation completed.")
            break

# Assign startups and display the schedule
assign_startups()

# Display results
print("\nMentor Schedules:\n")
for mentor, schedule in mentor_schedule.items():
    print(f"Mentor: {mentor}")
    for time, startup_idx in schedule:
        print(f"  Time: {time}, Startup Index: {startup_idx}, Name: {startups.loc[startup_idx, 'Name']}")
    print("\n")

# Display the count of mentor allocations for each startup
print("\nStartup Allocation Counts:\n")
for startup_idx, count in startup_mentor_count.items():
    print(f"Startup Index: {startup_idx}, Name: {startups.loc[startup_idx, 'Name']}, Allocations: {count}")

print("[INFO] Mentor scheduling completed.")
# Out:
# [INFO] Data loaded and missing values filled.
# [INFO] Time slots initialized.
# [INFO] Sector-wise distribution of startups completed.
# [INFO] Mentor tracking and schedule initialized.
# [INFO] Starting the assignment of startups to mentors.
# [DEBUG] Completed one round of unallocated startups.
# [DEBUG] Completed one round of unallocated startups.
# [DEBUG] Completed one round of unallocated startups.
# [DEBUG] Completed one round of unallocated startups.
# [DEBUG] Completed one round of unallocated startups.
# [DEBUG] Completed one round of unallocated startups.
# [DEBUG] Completed one round of unallocated startups.
# [DEBUG] Completed one round of unallocated startups.
# [DEBUG] Completed one round of unallocated startups.
# [DEBUG] Completed one round of unallocated startups.
# [DEBUG] All startups have been allocated at least once.
# [DEBUG] Repetition allocation completed.
#
# Mentor Schedules:
#
# Mentor: Mentor 1
#   Time: 11:00, Startup Index: 40, Name: Startup 41
#   Time: 11:20, Startup Index: 69, Name: Startup 70
#   Time: 11:40, Startup Index: 122, Name: Startup 123
#
#
# Mentor: Mentor 2
#   Time: 11:00, Startup Index: 39, Name: Startup 40
#   Time: 11:20, Startup Index: 89, Name: Startup 90
#
#
# Mentor: Mentor 3
#   Time: 11:00, Startup Index: 10, Name: Startup 11
#   Time: 11:20, Startup Index: 106, Name: Startup 107
#   Time: 11:40, Startup Index: 84, Name: Startup 85
#   Time: 12:00, Startup Index: 102, Name: Startup 103
#
#
# Mentor: Mentor 4
#   Time: 11:00, Startup Index: 72, Name: Startup 73
#   Time: 11:20, Startup Index: 85, Name: Startup 86
#
#
# Mentor: Mentor 5
#   Time: 11:00, Startup Index: 16, Name: Startup 17
#   Time: 11:40, Startup Index: 146, Name: Startup 147
#
#
# Mentor: Mentor 48
#   Time: 11:00, Startup Index: 88, Name: Startup 89
#
#
# Mentor: Mentor 49
#   Time: 11:00, Startup Index: 56, Name: Startup 57
#   Time: 11:20, Startup Index: 65, Name: Startup 66
#
#
# Mentor: Mentor 50
#   Time: 11:00, Startup Index: 66, Name: Startup 67
#   Time: 11:20, Startup Index: 109, Name: Startup 110
#   Time: 11:40, Startup Index: 126, Name: Startup 127
#   Time: 12:00, Startup Index: 148, Name: Startup 149
#
#
#
# Startup Allocation Counts:
#
# Startup Index: 10, Name: Startup 11, Allocations: 1
# Startup Index: 72, Name: Startup 73, Allocations: 1
# Startup Index: 16, Name: Startup 17, Allocations: 1
# Startup Index: 0, Name: Startup 1 , Allocations: 1
# Startup Index: 82, Name: Startup 83, Allocations: 1
# Startup Index: 4, Name: Startup 5, Allocations: 1
# Startup Index: 8, Name: Startup 9, Allocations: 1
# Startup Index: 18, Name: Startup 19, Allocations: 1
# Startup Index: 5, Name: Startup 6, Allocations: 1
# Startup Index: 7, Name: Startup 8, Allocations: 1
# Startup Index: 27, Name: Startup 28, Allocations: 1
# Startup Index: 33, Name: Startup 34, Allocations: 1
# Startup Index: 9, Name: Startup 10, Allocations: 1
# Startup Index: 13, Name: Startup 14, Allocations: 1
# Startup Index: 12, Name: Startup 13, Allocations: 1
# Startup Index: 21, Name: Startup 22, Allocations: 1
# Startup Index: 3, Name: Startup 4, Allocations: 1
# Startup Index: 2, Name: Startup 3, Allocations: 1
# Startup Index: 17, Name: Startup 18, Allocations: 1
# Startup Index: 53, Name: Startup 54, Allocations: 1
# Startup Index: 25, Name: Startup 26, Allocations: 1
# Startup Index: 14, Name: Startup 15, Allocations: 1
# Startup Index: 68, Name: Startup 69, Allocations: 1
# Startup Index: 23, Name: Startup 24, Allocations: 1
# Startup Index: 31, Name: Startup 32, Allocations: 1
# Startup Index: 19, Name: Startup 20, Allocations: 1
# Startup Index: 91, Name: Startup 92, Allocations: 1
# Startup Index: 20, Name: Startup 21, Allocations: 1
# Startup Index: 15, Name: Startup 16, Allocations: 1
# Startup Index: 1, Name: Startup 2, Allocations: 1
# Startup Index: 6, Name: Startup 7, Allocations: 1
# Startup Index: 36, Name: Startup 37, Allocations: 1
# Startup Index: 92, Name: Startup 93, Allocations: 1
# Startup Index: 97, Name: Startup 98, Allocations: 1
# Startup Index: 45, Name: Startup 46, Allocations: 1
# Startup Index: 32, Name: Startup 33, Allocations: 1
# Startup Index: 75, Name: Startup 76, Allocations: 1
# Startup Index: 51, Name: Startup 52, Allocations: 1
# Startup Index: 56, Name: Startup 57, Allocations: 1
# Startup Index: 66, Name: Startup 67, Allocations: 1
# Startup Index: 40, Name: Startup 41, Allocations: 1
# Startup Index: 39, Name: Startup 40, Allocations: 1
# Startup Index: 106, Name: Startup 107, Allocations: 1
# Startup Index: 61, Name: Startup 62, Allocations: 1
# Startup Index: 26, Name: Startup 27, Allocations: 1
# Startup Index: 58, Name: Startup 59, Allocations: 1
# Startup Index: 24, Name: Startup 25, Allocations: 1
# Startup Index: 11, Name: Startup 12, Allocations: 1
# Startup Index: 115, Name: Startup 116, Allocations: 1
# Startup Index: 76, Name: Startup 77, Allocations: 1
# Startup Index: 34, Name: Startup 35, Allocations: 1
# Startup Index: 73, Name: Startup 74, Allocations: 1
# Startup Index: 38, Name: Startup 39, Allocations: 1
# Startup Index: 141, Name: Startup 142, Allocations: 1
# Startup Index: 78, Name: Startup 79, Allocations: 1
# Startup Index: 43, Name: Startup 44, Allocations: 1
# Startup Index: 81, Name: Startup 82, Allocations: 1
# Startup Index: 29, Name: Startup 30, Allocations: 1
# Startup Index: 60, Name: Startup 61, Allocations: 1
# Startup Index: 71, Name: Startup 72, Allocations: 1
# Startup Index: 62, Name: Startup 63, Allocations: 1
# Startup Index: 22, Name: Startup 23, Allocations: 1
# Startup Index: 80, Name: Startup 81, Allocations: 1
# Startup Index: 28, Name: Startup 29, Allocations: 1
# Startup Index: 48, Name: Startup 49, Allocations: 1
# Startup Index: 59, Name: Startup 60, Allocations: 1
# Startup Index: 86, Name: Startup 87, Allocations: 1
# Startup Index: 35, Name: Startup 36, Allocations: 1
# Startup Index: 54, Name: Startup 55, Allocations: 1
# Startup Index: 63, Name: Startup 64, Allocations: 1
# Startup Index: 74, Name: Startup 75, Allocations: 1
# Startup Index: 105, Name: Startup 106, Allocations: 1
# Startup Index: 90, Name: Startup 91, Allocations: 1
# Startup Index: 65, Name: Startup 66, Allocations: 1
# Startup Index: 109, Name: Startup 110, Allocations: 1
# Startup Index: 69, Name: Startup 70, Allocations: 1
# Startup Index: 89, Name: Startup 90, Allocations: 1
# Startup Index: 84, Name: Startup 85, Allocations: 1
# Startup Index: 85, Name: Startup 86, Allocations: 1
# Startup Index: 112, Name: Startup 113, Allocations: 1
# Startup Index: 94, Name: Startup 95, Allocations: 1
# Startup Index: 41, Name: Startup 42, Allocations: 1
# Startup Index: 46, Name: Startup 47, Allocations: 1
# Startup Index: 83, Name: Startup 84, Allocations: 1
# Startup Index: 132, Name: Startup 133, Allocations: 1
# Startup Index: 108, Name: Startup 109, Allocations: 1
# Startup Index: 77, Name: Startup 78, Allocations: 1
# Startup Index: 42, Name: Startup 43, Allocations: 1
# Startup Index: 64, Name: Startup 65, Allocations: 1
# Startup Index: 142, Name: Startup 143, Allocations: 1
# Startup Index: 113, Name: Startup 114, Allocations: 1
# Startup Index: 101, Name: Startup 102, Allocations: 1
# Startup Index: 116, Name: Startup 117, Allocations: 1
# Startup Index: 120, Name: Startup 121, Allocations: 1
# Startup Index: 47, Name: Startup 48, Allocations: 1
# Startup Index: 128, Name: Startup 129, Allocations: 1
# Startup Index: 44, Name: Startup 45, Allocations: 1
# Startup Index: 145, Name: Startup 146, Allocations: 1
# Startup Index: 49, Name: Startup 50, Allocations: 1
# Startup Index: 99, Name: Startup 100, Allocations: 1
# Startup Index: 79, Name: Startup 80, Allocations: 1
# Startup Index: 100, Name: Startup 101, Allocations: 1
# Startup Index: 117, Name: Startup 118, Allocations: 1
# Startup Index: 121, Name: Startup 122, Allocations: 1
# Startup Index: 88, Name: Startup 89, Allocations: 1
# Startup Index: 126, Name: Startup 127, Allocations: 1
# Startup Index: 122, Name: Startup 123, Allocations: 1
# Startup Index: 102, Name: Startup 103, Allocations: 1
# Startup Index: 50, Name: Startup 51, Allocations: 1
# Startup Index: 52, Name: Startup 53, Allocations: 1
# Startup Index: 129, Name: Startup 130, Allocations: 1
# Startup Index: 130, Name: Startup 131, Allocations: 1
# Startup Index: 143, Name: Startup 144, Allocations: 1
# Startup Index: 136, Name: Startup 137, Allocations: 1
# Startup Index: 124, Name: Startup 125, Allocations: 1
# Startup Index: 57, Name: Startup 58, Allocations: 1
# Startup Index: 147, Name: Startup 148, Allocations: 1
# Startup Index: 107, Name: Startup 108, Allocations: 1
# Startup Index: 137, Name: Startup 138, Allocations: 1
# Startup Index: 127, Name: Startup 128, Allocations: 1
# Startup Index: 30, Name: Startup 31, Allocations: 1
# Startup Index: 55, Name: Startup 56, Allocations: 1
# Startup Index: 103, Name: Startup 104, Allocations: 1
# Startup Index: 70, Name: Startup 71, Allocations: 1
# Startup Index: 114, Name: Startup 115, Allocations: 1
# Startup Index: 139, Name: Startup 140, Allocations: 1
# Startup Index: 123, Name: Startup 124, Allocations: 1
# Startup Index: 144, Name: Startup 145, Allocations: 1
# Startup Index: 146, Name: Startup 147, Allocations: 1
# Startup Index: 148, Name: Startup 149, Allocations: 1
# Startup Index: 111, Name: Startup 112, Allocations: 1
# Startup Index: 125, Name: Startup 126, Allocations: 1
# Startup Index: 93, Name: Startup 94, Allocations: 1
# Startup Index: 131, Name: Startup 132, Allocations: 1
# Startup Index: 149, Name: Startup 150, Allocations: 1
# Startup Index: 37, Name: Startup 38, Allocations: 1
# Startup Index: 96, Name: Startup 97, Allocations: 1
# Startup Index: 67, Name: Startup 68, Allocations: 1
# Startup Index: 98, Name: Startup 99, Allocations: 1
# Startup Index: 133, Name: Startup 134, Allocations: 1
# Startup Index: 135, Name: Startup 136, Allocations: 1
# Startup Index: 104, Name: Startup 105, Allocations: 1
# Startup Index: 87, Name: Startup 88, Allocations: 1
# Startup Index: 95, Name: Startup 96, Allocations: 1
# Startup Index: 110, Name: Startup 111, Allocations: 1
# Startup Index: 118, Name: Startup 119, Allocations: 1
# Startup Index: 134, Name: Startup 135, Allocations: 1
# Startup Index: 119, Name: Startup 120, Allocations: 1
# Startup Index: 138, Name: Startup 139, Allocations: 1
# Startup Index: 140, Name: Startup 141, Allocations: 1
# [INFO] Mentor scheduling completed.
