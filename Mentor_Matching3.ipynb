# %%
import pandas as pd
import datetime
from collections import defaultdict

# Step 1: Load the CSV files for startups and mentors
startups = pd.read_csv("Startups.csv")
mentors = pd.read_csv("Mentor.csv")

# Step 2: Fill empty fields with "any"
startups.fillna("any", inplace=True)
mentors.fillna("any", inplace=True)

# Step 3: Assign weights to preferences
preference_weights = {1: 0.5, 2: 0.3, 3: 0.2}

# Step 4: Initialize time slots and schedules
start_time = datetime.datetime.strptime("11:00", "%H:%M")
end_time = datetime.datetime.strptime("14:00", "%H:%M")
time_slot_duration = datetime.timedelta(minutes=15)
gap_duration = datetime.timedelta(minutes=5)

# Mentor schedule dictionary
mentor_schedule = defaultdict(list)
allocated_startups = set()
mentor_startup_tracker = defaultdict(set)  # Tracks which startups each mentor has already met
startup_meeting_count = defaultdict(int)  # Tracks how many times each startup has been assigned

# Step 5: Sort startups based on their stage and preferences
def assign_startups():
    global allocated_startups

    while True:
        unallocated_startups = set(startups.index) - allocated_startups

        # Break if no unallocated startups are left
        if not unallocated_startups:
            break

        for _, mentor in mentors.iterrows():
            mentor_name = mentor['Name']
            sector_preferences = [mentor['Sector 1'], mentor['Sector 2'], mentor['Sector 3']]

            # Create a sorted list of startups for the mentor based on preference and stage
            startup_scores = []

            for i in unallocated_startups:
                startup = startups.loc[i]
                score = 0
                if startup['sector'] in sector_preferences:
                    score += preference_weights[sector_preferences.index(startup['sector']) + 1]

                startup_scores.append((score, i))

            # Sort by score in descending order
            startup_scores.sort(reverse=True, key=lambda x: x[0])

            # Allocate startups to mentor's schedule
            current_time = start_time if not mentor_schedule[mentor_name] else datetime.datetime.strptime(mentor_schedule[mentor_name][-1][0], "%H:%M") + time_slot_duration + gap_duration
            current_time = max(current_time, start_time)  # Ensure time advances correctly

            for _, startup_idx in startup_scores:
                if startup_idx in allocated_startups:
                    continue

                if current_time >= end_time:
                    return

                # Assign time slot
                mentor_schedule[mentor_name].append((current_time.strftime("%H:%M"), startup_idx))
                mentor_startup_tracker[mentor_name].add(startup_idx)
                allocated_startups.add(startup_idx)
                startup_meeting_count[startup_idx] += 1
                break

    # Allow repetition after all startups are assigned at least once
    while True:
        for _, mentor in mentors.iterrows():
            mentor_name = mentor['Name']
            sector_preferences = [mentor['Sector 1'], mentor['Sector 2'], mentor['Sector 3']]

            current_time = start_time if not mentor_schedule[mentor_name] else datetime.datetime.strptime(mentor_schedule[mentor_name][-1][0], "%H:%M") + time_slot_duration + gap_duration

            if current_time >= end_time:
                return

            # Create a sorted list of startups for the mentor based on preference and stage
            startup_scores = []

            for i in startups.index:
                if i in mentor_startup_tracker[mentor_name]:
                    continue  # Skip startups already met by this mentor

                startup = startups.loc[i]
                score = 0
                if startup['sector'] in sector_preferences:
                    score += preference_weights[sector_preferences.index(startup['sector']) + 1]

                startup_scores.append((score, i))

            # Sort by score in descending order
            startup_scores.sort(reverse=True, key=lambda x: x[0])

            for _, startup_idx in startup_scores:
                current_time = start_time if not mentor_schedule[mentor_name] else datetime.datetime.strptime(mentor_schedule[mentor_name][-1][0], "%H:%M") + time_slot_duration + gap_duration

#   Time: 13:40, Startup Index: 65
#
#
# Mentor: Mentor 49
#   Time: 11:00, Startup Index: 65
#   Time: 11:20, Startup Index: 100
#   Time: 11:40, Startup Index: 118
#   Time: 12:00, Startup Index: 18
#   Time: 12:20, Startup Index: 56
#   Time: 12:40, Startup Index: 83
#   Time: 13:00, Startup Index: 88
#   Time: 13:20, Startup Index: 102
#   Time: 13:40, Startup Index: 143
#
#
# Mentor: Mentor 50
#   Time: 11:00, Startup Index: 76
#   Time: 11:20, Startup Index: 130
#   Time: 11:40, Startup Index: 125
#   Time: 12:00, Startup Index: 20
#   Time: 12:20, Startup Index: 32
#   Time: 12:40, Startup Index: 51
#   Time: 13:00, Startup Index: 66
#   Time: 13:20, Startup Index: 105
#   Time: 13:40, Startup Index: 109
#
#
# Startup Assignment Count:
# Startup Index 9: Assigned 6 times
# Startup Index 5: Assigned 4 times
# Startup Index 10: Assigned 9 times
# Startup Index 72: Assigned 4 times
# Startup Index 16: Assigned 3 times
# Startup Index 0: Assigned 4 times
# Startup Index 82: Assigned 4 times
# Startup Index 4: Assigned 3 times
# Startup Index 1: Assigned 3 times
# Startup Index 27: Assigned 9 times
# Startup Index 3: Assigned 4 times
# Startup Index 8: Assigned 4 times
# Startup Index 20: Assigned 5 times
# Startup Index 18: Assigned 4 times
# Startup Index 13: Assigned 4 times
# Startup Index 7: Assigned 4 times
# Startup Index 32: Assigned 5 times
# Startup Index 53: Assigned 7 times
# Startup Index 68: Assigned 3 times
# Startup Index 12: Assigned 6 times
# Startup Index 39: Assigned 3 times
# Startup Index 19: Assigned 3 times
# Startup Index 21: Assigned 4 times
# Startup Index 15: Assigned 4 times
# Startup Index 2: Assigned 3 times
# Startup Index 17: Assigned 3 times
# Startup Index 60: Assigned 4 times
# Startup Index 25: Assigned 6 times
# Startup Index 14: Assigned 1 times
# Startup Index 75: Assigned 3 times
# Startup Index 11: Assigned 3 times
# Startup Index 23: Assigned 3 times
# Startup Index 31: Assigned 5 times
# Startup Index 24: Assigned 3 times
# Startup Index 56: Assigned 4 times
# Startup Index 91: Assigned 7 times
# Startup Index 92: Assigned 7 times
# Startup Index 71: Assigned 4 times
# Startup Index 28: Assigned 3 times
# Startup Index 6: Assigned 3 times
# Startup Index 36: Assigned 4 times
# Startup Index 97: Assigned 7 times
# Startup Index 106: Assigned 7 times
# Startup Index 45: Assigned 4 times
# Startup Index 51: Assigned 5 times
# Startup Index 78: Assigned 3 times
# Startup Index 66: Assigned 5 times
# Startup Index 86: Assigned 4 times
# Startup Index 65: Assigned 4 times
# Startup Index 76: Assigned 5 times
# Startup Index 40: Assigned 5 times
# Startup Index 73: Assigned 3 times
# Startup Index 115: Assigned 1 times
# Startup Index 43: Assigned 5 times
# Startup Index 33: Assigned 3 times
# Startup Index 26: Assigned 3 times
# Startup Index 58: Assigned 4 times
# Startup Index 29: Assigned 3 times
# Startup Index 35: Assigned 3 times
# Startup Index 141: Assigned 1 times
# Startup Index 62: Assigned 4 times
# Startup Index 63: Assigned 4 times
# Startup Index 105: Assigned 5 times
# Startup Index 83: Assigned 3 times
# Startup Index 81: Assigned 3 times
# Startup Index 38: Assigned 3 times
# Startup Index 109: Assigned 5 times
# Startup Index 89: Assigned 4 times
# Startup Index 80: Assigned 3 times
# Startup Index 59: Assigned 4 times
# Startup Index 132: Assigned 3 times
# Startup Index 41: Assigned 3 times
# Startup Index 64: Assigned 3 times
# Startup Index 69: Assigned 3 times
# Startup Index 34: Assigned 3 times
# Startup Index 48: Assigned 3 times
# Startup Index 101: Assigned 2 times
# Startup Index 77: Assigned 1 times
# Startup Index 22: Assigned 1 times
# Startup Index 90: Assigned 3 times
# Startup Index 46: Assigned 3 times
# Startup Index 108: Assigned 3 times
# Startup Index 116: Assigned 1 times
# Startup Index 42: Assigned 3 times
# Startup Index 88: Assigned 3 times
# Startup Index 145: Assigned 4 times
# Startup Index 102: Assigned 4 times
# Startup Index 30: Assigned 2 times
# Startup Index 47: Assigned 3 times
# Startup Index 54: Assigned 3 times
# Startup Index 74: Assigned 4 times
# Startup Index 117: Assigned 3 times
# Startup Index 122: Assigned 1 times
# Startup Index 79: Assigned 3 times
# Startup Index 121: Assigned 1 times
# Startup Index 120: Assigned 3 times
# Startup Index 126: Assigned 1 times
# Startup Index 143: Assigned 3 times
# Startup Index 100: Assigned 4 times
# Startup Index 130: Assigned 1 times
# Startup Index 124: Assigned 1 times
# Startup Index 128: Assigned 4 times
# Startup Index 149: Assigned 1 times
# Startup Index 127: Assigned 1 times
# Startup Index 142: Assigned 1 times
# Startup Index 84: Assigned 3 times
# Startup Index 131: Assigned 1 times
# Startup Index 44: Assigned 3 times
# Startup Index 134: Assigned 1 times
# Startup Index 129: Assigned 2 times
# Startup Index 147: Assigned 3 times
# Startup Index 133: Assigned 1 times
# Startup Index 139: Assigned 1 times
# Startup Index 136: Assigned 1 times
# Startup Index 94: Assigned 4 times
# Startup Index 137: Assigned 1 times
# Startup Index 144: Assigned 1 times
# Startup Index 135: Assigned 1 times
# Startup Index 61: Assigned 2 times
# Startup Index 99: Assigned 2 times
# Startup Index 146: Assigned 1 times
# Startup Index 50: Assigned 3 times
# Startup Index 107: Assigned 1 times
# Startup Index 138: Assigned 2 times
# Startup Index 111: Assigned 1 times
# Startup Index 113: Assigned 3 times
# Startup Index 140: Assigned 1 times
# Startup Index 148: Assigned 1 times
# Startup Index 37: Assigned 1 times
# Startup Index 85: Assigned 2 times
# Startup Index 49: Assigned 3 times
# Startup Index 114: Assigned 1 times
# Startup Index 123: Assigned 1 times
# Startup Index 57: Assigned 3 times
# Startup Index 52: Assigned 4 times
# Startup Index 55: Assigned 2 times
# Startup Index 67: Assigned 2 times
# Startup Index 70: Assigned 1 times
# Startup Index 93: Assigned 1 times
# Startup Index 87: Assigned 2 times
# Startup Index 103: Assigned 1 times
# Startup Index 95: Assigned 2 times
# Startup Index 96: Assigned 1 times
# Startup Index 98: Assigned 1 times
# Startup Index 119: Assigned 2 times
# Startup Index 104: Assigned 1 times
# Startup Index 110: Assigned 1 times
# Startup Index 112: Assigned 2 times
# Startup Index 118: Assigned 1 times
# Startup Index 125: Assigned 1 times
