# %%
import pandas as pd
import datetime
import random
from collections import defaultdict

# Load data
startups = pd.read_csv("Startups.csv")
mentors = pd.read_csv("Mentor.csv")

# Fill empty fields with "any"
startups.fillna("any", inplace=True)
mentors.fillna("any", inplace=True)

# Initialize time slots and schedules
start_time = datetime.datetime.strptime("11:00", "%H:%M")
end_time = datetime.datetime.strptime("14:00", "%H:%M")
time_slot_duration = datetime.timedelta(minutes=15)
gap_duration = datetime.timedelta(minutes=5)

# Sector-wise distribution of startups
sector_startups = defaultdict(list)
for idx, row in startups.iterrows():
    sector_startups[row['sector']].append(idx)

# Mentor schedule and tracking
mentor_schedule = defaultdict(list)
mentor_startup_tracker = defaultdict(set)  # Tracks which startups each mentor has met
allocated_startups = set()

# Probability distribution function
def get_startup_by_preference(mentor, preferences):
    """
    Select a startup based on the mentor's preferences and probability ratio 5:3:2.
    """
    probabilities = [0.5, 0.3, 0.2]
    for i, sector in enumerate(preferences):
        if sector in sector_startups and sector_startups[sector]:
            if random.random() <= probabilities[i]:  # Check probability
                return sector_startups[sector].pop(0)  # Allocate a startup
    return None  # No startup could be allocated from preferences

# Assign startups to mentors
def assign_startups():
    global allocated_startups
    while True:
        unallocated_startups = set(startups.index) - allocated_startups

        # Break if no unallocated startups are left
        if not unallocated_startups:
            break

        for _, mentor in mentors.iterrows():
            mentor_name = mentor['Name']
            preferences = [mentor['Sector 1'], mentor['Sector 2'], mentor['Sector 3']]

            # Allocate a startup based on preference probabilities
            current_time = start_time if not mentor_schedule[mentor_name] else datetime.datetime.strptime(
                mentor_schedule[mentor_name][-1][0], "%H:%M"
            ) + time_slot_duration + gap_duration
            current_time = max(current_time, start_time)  # Ensure time advances correctly

            if current_time >= end_time:
                return

            startup_idx = get_startup_by_preference(mentor, preferences)
            if startup_idx is None:
                continue

            # Assign time slot and update tracking
            mentor_schedule[mentor_name].append((current_time.strftime("%H:%M"), startup_idx))
            mentor_startup_tracker[mentor_name].add(startup_idx)
            allocated_startups.add(startup_idx)

    # Allow repetition after all startups are assigned at least once
    while True:
        for _, mentor in mentors.iterrows():
            mentor_name = mentor['Name']
            preferences = [mentor['Sector 1'], mentor['Sector 2'], mentor['Sector 3']]

            current_time = start_time if not mentor_schedule[mentor_name] else datetime.datetime.strptime(
                mentor_schedule[mentor_name][-1][0], "%H:%M"
            ) + time_slot_duration + gap_duration

            if current_time >= end_time:
                return

            startup_idx = get_startup_by_preference(mentor, preferences)
            if startup_idx is None or startup_idx in mentor_startup_tracker[mentor_name]:
                continue  # Skip already met startups

            # Assign time slot and update tracking
            mentor_schedule[mentor_name].append((current_time.strftime("%H:%M"), startup_idx))
            mentor_startup_tracker[mentor_name].add(startup_idx)

# Assign startups and display the schedule
assign_startups()

# Display results
for mentor, schedule in mentor_schedule.items():
    print(f"Mentor: {mentor}")
    for time, startup_idx in schedule:
        print(f"  Time: {time}, Startup Index: {startup_idx}, Name: {startups.loc[startup_idx, 'Name']}")
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 96
#      93             mentor_startup_tracker[mentor_name].add(startup_idx)
#      95 # Assign startups and display the schedule
# ---> 96 assign_startups()
#      98 # Display results
#      99 for mentor, schedule in mentor_schedule.items():
#
# Cell In[1], line 76, in assign_startups()
#      74 # Allow repetition after all startups are assigned at least once
#      75 while True:
# ---> 76     for _, mentor in mentors.iterrows():
#      77         mentor_name = mentor['Name']
#      78         preferences = [mentor['Sector 1'], mentor['Sector 2'], mentor['Sector 3']]
#
# File c:\Users\medhr\anaconda3\Lib\site-packages\pandas\core\frame.py:1554, in DataFrame.iterrows(self)
#    1552 using_cow = using_copy_on_write()
#    1553 for k, v in zip(self.index, self.values):
# -> 1554     s = klass(v, index=columns, name=k).__finalize__(self)
#    1555     if using_cow and self._mgr.is_single_block:
#    1556         s._mgr.add_references(self._mgr)  # type: ignore[arg-type]
#
# File c:\Users\medhr\anaconda3\Lib\site-packages\pandas\core\series.py:593, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     590         data = SingleArrayManager.from_array(data, index)
#     592 NDFrame.__init__(self, data)
# --> 593 self.name = name
#     594 self._set_axis(0, index)
#     596 if original_dtype is None and is_pandas_object and data_dtype == np.object_:
#
# File c:\Users\medhr\anaconda3\Lib\site-packages\pandas\core\generic.py:6320, in NDFrame.__setattr__(self, name, value)
#    6317 # if this fails, go on to more involved attribute setting
#    6318 # (note that this matches __getattr__, above).
#    6319 if name in self._internal_names_set:
# -> 6320     object.__setattr__(self, name, value)
#    6321 elif name in self._metadata:
#    6322     object.__setattr__(self, name, value)
#
# File c:\Users\medhr\anaconda3\Lib\site-packages\pandas\core\series.py:786, in Series.name(self, value)
#     784 @name.setter
#     785 def name(self, value: Hashable) -> None:
# --> 786     validate_all_hashable(value, error_name=f"{type(self).__name__}.name")
#     787     object.__setattr__(self, "_name", value)
#
# File c:\Users\medhr\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1571, in validate_all_hashable(error_name, *args)
#    1564     if typ not in ["generic", "ns"]:
#    1565         raise ValueError(
#    1566             f"{repr(dtype.name)} is too specific of a frequency, "
#    1567             f"try passing {repr(dtype.type.__name__)}"
#    1568         )
# -> 1571 def validate_all_hashable(*args, error_name: str | None = None) -> None:
#    1572     """
#    1573     Return None if all args are hashable, else raise a TypeError.
#    1574
#    (...)
#    1588     None
#    1589     """
#    1590     if not all(is_hashable(arg) for arg in args):
#
# KeyboardInterrupt:
